# %% [markdown]
# This is the project for behavioral Cloning in Udacity Self Driving Car Course.

# %% [markdown]
# First, I will follow the instructor and run the code for a visible result.

# %%
import matplotlib.pyplot as plt
import random
import cv2
import numpy as np
import csv
# Visualizations will be shown in the notebook.
# %matplotlib inline
lines = []
with open('driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
print('read csv file done')
images = []
measurements = []
for line in lines:
    print('print first line: ',line)
    image = cv2.imread(line[0]) # read the center image
    
    #fig = plt.figure(figsize=(20,8))
    #plt.imshow(image)
    #break
    
    measurement = float(line[3])
    measurements.append(measurement)
    images.append(image)
    
x_train = np.array(images)
y_train = np.array(measurements)

print('done')
# Out:
# read csv file done
# print first line:  ['IMG/center_2016_12_01_13_30_48_287.jpg', ' IMG/left_2016_12_01_13_30_48_287.jpg', ' IMG/right_2016_12_01_13_30_48_287.jpg', ' 0', ' 0', ' 0', ' 22.14829']
# done

# %% [markdown]
# build the training mode using keras

# %%
from keras.model import Sequential
from keras.layer import Flatten, Dense

model = Sequential()
model.add(Flatten(input_shape=(160,320,3)))
model.add(Dense(1))
model.compile(loss='mse',optimizer='adam')
model.fit(x_train,y_train,validation_split = 0.2,shuffle=True,nb_epoch=7)

model.save('model.h5')
